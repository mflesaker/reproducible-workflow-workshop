# %% [markdown]
# # Setup Check!
#
# Michelle Flesaker
# January 10, 2026
#
# ## Instructions
#
# 1.  Replace `"YOUR NAME"` above with your actual name
# 2.  Render this document (Ctrl+Shift+K or Cmd+Shift+K)
# 3.  If successful, commit and push this file (the rendered output is ignored by Git)
#
# ## Environment Check
#
# The code below verifies that your R packages are installed correctly.

# %%
#| label: package-check
#| message: false

# Load required packages
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# here() starts at /Users/michelleflesaker/Documents/PhD/reproducible-workflow-workshop

# %% [markdown]
# If the above runs without errors, your packages are correctly installed.
#
# ## Quick Test

# %%
#| label: tbl-test
#| tbl-cap: "Baseline characteristics of NHANES participants"

NHANES |>
  select(Age, Gender, BMI, BPSysAve) |>
  head(100) |>
  tbl_summary(
    by = Gender,
    statistic = list(all_continuous() ~ "{mean} ({sd})"),
    missing = "no"
  )
# Out:
#   -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   [**Characteristic**]{.quarto-scaffold}                                            [**female**\                                                                      [**male**\
#                                                                                     N = 49]{.quarto-scaffold}[^1^]{.gt_footnote_marks                                 N = 51]{.quarto-scaffold}[^1^]{.gt_footnote_marks
#                                                                                     style="white-space:nowrap;font-style:italic;font-weight:normal;line-height:0;"}   style="white-space:nowrap;font-style:italic;font-weight:normal;line-height:0;"}
# ...

# %% [markdown]
# ## Session Info

# %%
#| label: session-info

sessionInfo()
# Out:
# R version 4.5.1 (2025-06-13)
# Platform: aarch64-apple-darwin20
# Running under: macOS Sequoia 15.6.1
#
# Matrix products: default
# BLAS:   /Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.0.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRlapack.dylib;  LAPACK version 3.12.1
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# time zone: America/New_York
# tzcode source: internal
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] NHANES_2.1.0    here_1.0.2      gt_1.0.0        gtsummary_2.4.0
#  [5] lubridate_1.9.4 forcats_1.0.0   stringr_1.5.1   dplyr_1.1.4
#  [9] purrr_1.1.0     readr_2.1.5     tidyr_1.3.1     tibble_3.3.0
# [13] ggplot2_3.5.2   tidyverse_2.0.0
#
# loaded via a namespace (and not attached):
#  [1] sass_0.4.10        generics_0.1.4     xml2_1.4.0         stringi_1.8.7
# ...

# %% [markdown]
# ## Confirmation
#
# After rendering this document:
#
# -   [ ] The HTML file was created without errors
# -   [ ] The table above displays correctly
# -   [ ] I have committed and pushed my changes to the `.qmd` file
#
# **You’re ready for the workshop!**
